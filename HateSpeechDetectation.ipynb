# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("labeled_data.csv.zip")

# %%
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
dataset.isnull()
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           False  False        False               False    False  False
# 1           False  False        False               False    False  False
# 2           False  False        False               False    False  False
# 3           False  False        False               False    False  False
# 4           False  False        False               False    False  False
# ...           ...    ...          ...                 ...      ...    ...
# 24778       False  False        False               False    False  False
# 24779       False  False        False               False    False  False
# 24780       False  False        False               False    False  False
# 24781       False  False        False               False    False  False
# 24782       False  False        False               False    False  False
#
#        tweet
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
dataset.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %%
dataset.head(55)
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 1            1      3            0                   3        0      1
# 2            2      3            0                   3        0      1
# 3            3      3            0                   2        1      1
# 4            4      6            0                   6        0      1
# 5            5      3            1                   2        0      1
# 6            6      3            0                   3        0      1
# 7            7      3            0                   3        0      1
# 8            8      3            0                   3        0      1
# 9            9      3            1                   2        0      1
# 10          10      3            0                   3        0      1
# 11          11      3            0                   3        0      1
# ...

# %%
dataset["labels"] = dataset["class"].map({0:"Hate Speech",1:"Offensive Language",2:"No hate or Offensive Langauge"})

# %%
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet  \
# ...

# %%
dataset.tail(50)
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 24733       25246      3            1                   2        0      1
# 24734       25247      3            0                   3        0      1
# 24735       25248      3            0                   0        3      2
# 24736       25249      3            0                   0        3      2
# 24737       25250      3            0                   1        2      2
# 24738       25251      3            0                   3        0      1
# 24739       25252      3            0                   3        0      1
# 24740       25253      3            1                   2        0      1
# 24741       25254      3            0                   3        0      1
# 24742       25255      3            1                   2        0      1
# 24743       25256      3            0                   3        0      1
# 24744       25257      3            0                   3        0      1
# ...

# %%
data = dataset[["tweet","labels"]]

# %%
data
# Out:
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                               labels
# 0      No hate or Offensive Langauge
# 1                 Offensive Language
# 2                 Offensive Language
# 3                 Offensive Language
# 4                 Offensive Language
# ...                              ...
# ...

# %%
data.tail(50)
# Out:
#                                                    tweet  \
# 24733                     yall crazy hoes need jesus lol
# 24734                                yall pussies i swur
# 24735          yay I like when jacob has colored layouts
# 24736  yaya ho.. cute avi tho RT @ViVaLa_Ari I had no...
# 24737  yea so about @N_tel 's new friend.. all my fri...
# 24738  yeah I'm a bitch, but guess what? you're still...
# 24739    yeah I'm small den a hoe http://t.co/VV3qdTo7MG
# 24740  yeah i got soul i was brought up by colored wo...
# 24741   yeah these valley faggots can go fuck themselves
# 24742                yes good shapely eurotrash manbooty
# 24743  yet this nigga still checkin up on his old hoe...
# 24744  yo bitch bitch gone let me fuck tonight\nthurs...
# 24745                     yo bitch look like a boogawolf
# 24746  yo bitch want that vitamin D she lookin desperate
# 24747              yo bitch whippin in the early morning
# ...

# %%
import re    # get rid of symbols ,"regular expression - re"
import nltk  # Natural Language toolkit
import string

# %%
# Removal of stopwords and stemming the words

# %%
# Importing stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))

# %%
# Importing stemming

# %%
stemmer = nltk.SnowballStemmer("english")

# %%
# Data Cleaning

# %%
def clean_data(text):
    text = str(text).lower()
    text = re.sub(r"https?://\S+|www\.\S+", "", text)
    text = re.sub(r"\[.*?\]", "", text)
    text = re.sub(r"<.*?>+", "", text)
    text = re.sub(r"[%s]" % re.escape(string.punctuation), "", text)
    text = re.sub(r"\n", " ", text)
    text = re.sub(r"\w*\d\w*", "", text)
    
    # Stopwords removal
    text = [word for word in text.split() if word not in stop_words]
    text = " ".join(text)
    
    # Stemming
    text = [stemmer.stem(word) for word in text.split()]
    text = " ".join(text)
    
    return text

# %%
data["tweet"] = data["tweet"].apply(clean_data)
# Out:
# C:\Users\GaykwadChandrakanth\AppData\Local\Temp\ipykernel_25516\1832165696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["tweet"] = data["tweet"].apply(clean_data)

# %%
data
# Out:
#                                                    tweet  \
# 0      rt mayasolov woman shouldnt complain clean hou...
# 1       rt boy dat coldtyga dwn bad cuffin dat hoe place
# 2      rt urkindofbrand dawg rt ever fuck bitch start...
# 3                  rt cganderson vivaba look like tranni
# 4      rt shenikarobert shit hear might true might fa...
# ...                                                  ...
# 24778  yous muthafin lie coreyemanuel right tl trash ...
# 24779  youv gone broke wrong heart babi drove redneck...
# 24780  young buck wanna eat dat nigguh like aint fuck...
# 24781                     youu got wild bitch tellin lie
# 24782  ruffl ntac eileen dahlia beauti color combin p...
#
#                               labels
# 0      No hate or Offensive Langauge
# 1                 Offensive Language
# 2                 Offensive Language
# 3                 Offensive Language
# 4                 Offensive Language
# ...                              ...
# ...

# %%
x=np.array(data["tweet"])
y=np.array(data["labels"])

# %%
x
# Out:
# array(['rt mayasolov woman shouldnt complain clean hous amp man alway take trash',
#        'rt boy dat coldtyga dwn bad cuffin dat hoe place',
#        'rt urkindofbrand dawg rt ever fuck bitch start cri confus shit',
#        ..., 'young buck wanna eat dat nigguh like aint fuckin dis',
#        'youu got wild bitch tellin lie',
#        'ruffl ntac eileen dahlia beauti color combin pink orang yellow amp white coll'],
#       dtype=object)

# %%
y
# Out:
# array(['No hate or Offensive Langauge', 'Offensive Language',
#        'Offensive Language', ..., 'Offensive Language',
#        'Offensive Language', 'No hate or Offensive Langauge'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
cv=CountVectorizer()
X=cv.fit_transform(x)

# %%
X
# Out:
# <24783x25215 sparse matrix of type '<class 'numpy.int64'>'
# 	with 196817 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# <16604x25215 sparse matrix of type '<class 'numpy.int64'>'
# 	with 131856 stored elements in Compressed Sparse Row format>

# %%
# Building our ML Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(X_test)

# %%
# Confusion Matrix and accuracy
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 176,   35,  254],
#        [  83, 1096,  200],
#        [ 275,  204, 5856]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as ply
# %matplotlib inline

# %%
sns.heatmap(cm,annot=True,fmt="f",cmap="YlGnBu")
# Out:
# <Axes: >

# %%
ply.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8715001833965033

# %%
sample = "You’re such an idiot, stop talking nonsense."

# %%
sample = clean_data(sample)

# %%
sample
# Out:
# "you'r idiot stop talk nonsens"

# %%
data1 = cv.transform([sample]).toarray()

# %%
data1
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
dt.predict(data1)
# Out:
# array(['Offensive Language'], dtype=object)
